# %% [markdown]
# ## 作業1:請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# ### 1.這組資料為何重要
# #### 這組資料的提供者有提到，在網路上的許多公共數據庫可找到Apple App Store數據，卻沒有Google Play Store的對應數據。期許可以透過這組資料來分析Android各年齡層用戶偏好的應用程式類型，這對於進一步的應用程式開發來說，是一個相當有效的指標。
# ### 2.資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# #### 這組資料來自於kaggle網站上，一位ID名為Lavanya Gupta的用戶所提供，係以Google Play Store所提供的App資料蒐集。
# ### 3.蒐集而來的資料型態為何
# #### 這組資料有兩個csv檔，其中一個檔案內容為App的名稱、類別、評分、評論數量、大小、下載次數、免費/付費、價格、目標用戶年齡層、上次更新日期、版本、Android版本，共10842筆資料；另一個檔案內容為特定App的評論內容，共64164筆資料。
# ### 4.這組資料想解決的問題如何評估
# #### 使用AUC分辨App的類型之後，使用迴歸找出App類型與用戶年齡層之間的相關性，在評估App方面則使用迴歸找出評分與下載次數之間的相關等等

# %% [markdown]
# ## 作業2:
# ## 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# ### 1.核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# #### 假設將業績提升的指標定義為: 「載客量」、「載客哩程數」的上升，可使收益金額上升
# ### 2.資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# #### 如何蒐集: 將每一次載客的人數、時間、哩程數及收入紀錄下來
# ### 3.蒐集而來的資料型態為何
# #### 表格
# ### 4.你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# #### 將各資料統計後進行迴歸分析，是否載客量收益與呈正相關等等

# %% [markdown]
# ## 作業3: 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 13.207

# %%
def mean_squared_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    mse = MSE = sum((y-yp)**2) / len(y)
    return mse

MSE = mean_squared_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
# Out:
# The Mean squared error is 266.771

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 266.771
# The Mean absolute error is 13.207
